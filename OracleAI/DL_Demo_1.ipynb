# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.datasets import make_circles

# %%
# Generating synthetic data
X, y = make_circles(n_samples=300, noise=0.1, random_state=42, factor=0.5)

plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlGn, edgecolors='k', marker='o', s=50)
plt.show()

# %%
from sklearn.neural_network import MLPClassifier

# Creating Classifier
clf = MLPClassifier(hidden_layer_sizes=(8,), activation='relu', max_iter=3000, random_state=42)
clf.fit(X, y)
# Out:
# MLPClassifier(hidden_layer_sizes=(8,), max_iter=3000, random_state=42)

# %%
# Step 1: Define grid values for x and y
x_vals = np.linspace(X[:, 0].min() - 0.1, X[:, 0].max() + 0.1, 100)
y_vals = np.linspace(X[:, 1].min() - 0.1, X[:, 1].max() + 0.1, 100)

# Step 2: Create a meshgrid (100x100 = 10,000 points)
X_plane, Y_plane = np.meshgrid(x_vals, y_vals)

# Step 3: Flatten into coordinate pairs
grid_points = np.column_stack((X_plane.ravel(), Y_plane.ravel()))

# Step 4: Predict class for each grid point
Z = clf.predict(grid_points)

# Step 5: Reshape back into grid for visualization
Z = Z.reshape(X_plane.shape)

# Step 6: Predict labels for the original dataset
y_pred = clf.predict(X)

# %%
plt.contourf(X_plane, Y_plane, Z, alpha=0.3)   # decision regions
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlGn, edgecolor='k')  # actual data points
plt.show()
